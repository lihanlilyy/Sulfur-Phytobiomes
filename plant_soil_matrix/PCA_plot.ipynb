# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
from sklearn.preprocessing import StandardScaler 
from sklearn.preprocessing import MinMaxScaler

# %%
# importing or loading the dataset
dataset = pd.read_csv('PCA_metadata_filtered.csv', index_col=0)
dataset.head(5)
# Out:
#                  K00003  K00016  K00024  K00025  K00026  K00031  K00032  \
# GCF_014196405.1       1       0       1       0       0       1       0
# GCA_006717025.1       1       1       1       0       0       0       0
# GCF_900095735.1       1       0       1       0       0       1       0
# GCA_008000915.1       2       1       1       0       0       1       0
# GCF_002879615.1       1       0       1       0       0       1       1
#
#                  K00033  K00036  K00058  ...  K24138  K25035  K25210  K25261  \
# GCF_014196405.1       2       2       1  ...       1       0       0       0
# GCA_006717025.1       2       3       2  ...       0       0       0       0
# GCF_900095735.1       1       1       2  ...       0       0       0       0
# GCA_008000915.1       1       1       1  ...       1       0       0       0
# GCF_002879615.1       0       1       1  ...       2       0       0       0
#
#                  K25262  K25316  K25317  K25985  K26005  Sphere_number
# GCF_014196405.1       0       0       0       0       0              1
# GCA_006717025.1       0       1       0       0       0              2
# GCF_900095735.1       0       0       0       0       0              1
# GCA_008000915.1       0       0       0       0       0              1
# GCF_002879615.1       0       1       0       0       1              1
#
# [5 rows x 292 columns]

# %%
scaler = StandardScaler()
scaler.fit(dataset)
# Out:
# StandardScaler()

# %%
scaled_data = scaler.transform(dataset)

# %%
scaled_data
# Out:
# array([[-0.02556594, -0.39981098,  0.46557931, ..., -0.06049666,
#         -0.12537251, -2.09752652],
#        [-0.02556594,  1.00296226,  0.46557931, ..., -0.06049666,
#         -0.12537251, -0.59782444],
#        [-0.02556594, -0.39981098,  0.46557931, ..., -0.06049666,
#         -0.12537251, -2.09752652],
#        ...,
#        [-1.54317177, -0.39981098, -1.6303487 , ..., -0.06049666,
#         -0.12537251,  0.90187765],
#        [-1.54317177, -0.39981098, -1.6303487 , ..., -0.06049666,
#         -0.12537251,  0.90187765],
#        [-0.02556594,  1.00296226, -1.6303487 , ..., -0.06049666,
#         -0.12537251,  0.90187765]])

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 2)

# %%
pca.fit(scaled_data)
# Out:
# PCA(n_components=2)

# %%
x_pca = pca.transform(scaled_data)

# %%
scaled_data.shape
# Out:
# (5105, 292)

# %%
x_pca.shape
# Out:
# (5105, 2)

# %%
scaled_data
# Out:
# array([[-0.02556594, -0.39981098,  0.46557931, ..., -0.06049666,
#         -0.12537251, -2.09752652],
#        [-0.02556594,  1.00296226,  0.46557931, ..., -0.06049666,
#         -0.12537251, -0.59782444],
#        [-0.02556594, -0.39981098,  0.46557931, ..., -0.06049666,
#         -0.12537251, -2.09752652],
#        ...,
#        [-1.54317177, -0.39981098, -1.6303487 , ..., -0.06049666,
#         -0.12537251,  0.90187765],
#        [-1.54317177, -0.39981098, -1.6303487 , ..., -0.06049666,
#         -0.12537251,  0.90187765],
#        [-0.02556594,  1.00296226, -1.6303487 , ..., -0.06049666,
#         -0.12537251,  0.90187765]])

# %%
x_pca
# Out:
# array([[ 1.9352928 , -1.87215549],
#        [-1.62994618, -3.75837834],
#        [ 2.83418808,  0.17648399],
#        ...,
#        [-2.34345043, -0.25128531],
#        [-3.57318448, -4.57409824],
#        [-1.42840653, -4.30927923]])

# %%
plt.figure(figsize=(15,15))
plt.scatter(x_pca[:,0],x_pca[:,1], c=dataset['Sphere_number'], s=0.7)
plt.xlabel('PC1')
plt.xlabel('PC2')
# Out:
# Text(0.5, 0, 'PC2')
